# %%
import color_picker_lib

# %%
color_picker_lib.get_colors('f7ecde')
# Out:
# <h1>Original color</h1>
#    #f7ecde
# <PIL.Image.Image image mode=RGB size=100x100 at 0x2E9CD6D3FA0>
# <h1>Complementary color</h1>
#    #f7ecde      #dee9f7
# <PIL.Image.Image image mode=RGB size=200x100 at 0x2E9DCC6CC10>
# <h1>Triadic colors</h1>
#    #f7ecde      #def7ec      #ecdef7
# <PIL.Image.Image image mode=RGB size=300x100 at 0x2E9DCC6CC10>
# <h1>Split complementary colors</h1>
#    #f7ecde      #def6f7      #e0def7
# <PIL.Image.Image image mode=RGB size=300x100 at 0x2E9CD6D3E80>
# <h1>Tetradic colors</h1>
#    #f7ecde      #e9f7de      #dee9f7      #ecdef7
# <PIL.Image.Image image mode=RGB size=400x100 at 0x2E9DCCFAA30>
# <h1>Analogous colors</h1>
#    #f7ecde      #f6f7de      #f7e0de
# <PIL.Image.Image image mode=RGB size=300x100 at 0x2E9DCCFA370>
# <h1>Monochromatic colors</h1>
#    #f7ecde      #fff8e9      #eae0d3      #fffff5      #ded4c7      #f7e7d2      #f7f1ea      #fff2dc      #eae5de
# <PIL.Image.Image image mode=RGB size=900x100 at 0x2E9DCD13640>
# ...
